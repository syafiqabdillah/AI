# %%
import cv2
import tensorflow as tf
import matplotlib.pyplot as plt
import os

CATEGORIES = ["Cat", "Dog"]

# method to prepare the data before prediction 
def prepare(filepath):
    try:
        IMG_SIZE = 50 # resize the image 
        img_array = cv2.imread(filepath, cv2.IMREAD_GRAYSCALE) # grayscale the image
        new_array = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))
        return new_array.reshape(-1, IMG_SIZE, IMG_SIZE, 1)
    except Exception as e:
        pass
# Out:
# C:\Users\ASUS\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
# the images we want to predict 

DATADIR = "D:\Artificial Intelligence\Inta_img"

# %%
# loading the model 
model = tf.keras.models.load_model("catdog.model") # loading the model

# %%
# make prediction for each image, while displaying the image 
for img in os.listdir(DATADIR):  
    try:
        prediction = model.predict([prepare(os.path.join(DATADIR, img))]) # the prediction
        print(CATEGORIES[int(prediction[0][0])])
        # show the prepared image 
        
        img_array = cv2.imread(os.path.join(DATADIR, img), cv2.IMREAD_GRAYSCALE) 
        new_array = cv2.resize(img_array, (50, 50))
        
        plt.imshow(new_array, cmap="gray")
        plt.show() 
    except Exception as e:
        print(e)
        pass
# Out:
# Dog
# Dog
# Dog
# Cat
# Dog
# Cat
# Cat
# Dog
# Dog
# Cat
# Dog
# Cat
# Dog
# Cat
# Cat
# Dog
# Dog
# Cat

# %%
# my model still has a lot room for improvement a.k.a dumb af 

# second thought : i think the size must be higher, since i can't differentiate dog and cat in 50x50
